# %%
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

sns.set_style("whitegrid")
palette = sns.color_palette("husl", 3)
sns.set_palette(palette)

andy_theme = {'axes.grid': True,
              'grid.linestyle': '--',
              'legend.framealpha': 1,
              'legend.facecolor': 'white',
              'legend.shadow': False,
              'figure.dpi': 100,}
plt.rcParams.update(andy_theme)
plt.rc('text', usetex=True )
plt.rc('font', family='Times New Roman', weight='heavy', size=14)
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['mathtext.fontset'] = 'custom'

# %%
x = [1, 5, 9, 13, 17, 21, 25]
y_dict = { 'Aspect': 
          [0.058666666666666666, 0.08800000000000001, 0.09866666666666668, 0.10400000000000002, 0.08133333333333333, 0.09066666666666666, 0.05333333333333334],
          'Case':
          [0.06599999999999999, 0.06000000000000001, 0.054000000000000006, 0.078, 0.072, 0.088, 0.068],
          'Definiteness':
          [0.08, 0.08, 0.02, 0.06, 0.06, 0.08, 0.04],
          'Finiteness':
          [0.04666666666666667, 0.08, 0.16666666666666666, 0.09333333333333334, 0.10666666666666667, 0.08666666666666667, 0.07333333333333333],
          'Gender':
          [0.0642857142857143, 0.14357142857142854, 0.19714285714285712, 0.23857142857142857, 0.2307142857142857, 0.21857142857142858, 0.05285714285714287],
          'Mood':
          [0.05, 0.072, 0.084, 0.07800000000000001, 0.07200000000000001, 0.098, 0.06],
          'Number':
          [0.10654545454545455, 0.14145454545454544, 0.1738181818181818, 0.19745454545454547, 0.18145454545454545, 0.14799999999999996, 0.06618181818181819],
          'Person':
          [0.06, 0.08761904761904762, 0.08666666666666667, 0.09333333333333334, 0.10476190476190476, 0.09238095238095238, 0.05428571428571429],
          'POS':
          [0.07564102564102562, 0.09282051282051283, 0.12205128205128202, 0.1351282051282051, 0.13333333333333336, 0.12615384615384614, 0.06307692307692307],
          'Tense':
          [0.08133333333333333, 0.12666666666666668, 0.15466666666666665, 0.14533333333333334, 0.1426666666666667, 0.14266666666666666, 0.058666666666666686],
          'Voice':
          [0.08, 0.08, 0.06, 0.12, 0.1, 0.12, 0.08],
}

# %%
# Set the style and context
sns.set_style(style="whitegrid")
sns.set_style({'font.family':'serif', 'font.serif':'Times New Roman'})
plt.figure(figsize=(8, 6))

# Define a dark color palette
palette = sns.color_palette("husl", n_colors=len(y_dict))
markers = itertools.cycle(['o', 'x', '^', '+', '*', '8', 's', 'p', 'D'])

# Plot each category with a unique color
for (key, y), color in zip(y_dict.items(), itertools.cycle(palette)):
    plt.plot(x, y, marker=next(markers), label=key, color=color)

# Customize the grid and frame
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
# plt.gca().spines['top'].set_linewidth(0)
# plt.gca().spines['right'].set_linewidth(0)
plt.gca().spines['bottom'].set_linewidth(1.5)
plt.gca().spines['left'].set_linewidth(1.5)
plt.grid(True, which='major', linewidth=0.5, color='gray', linestyle='--')

plt.xticks(ticks=x)
plt.gca().spines['bottom'].set_position(('outward', 10))  # Move bottom spine outward
plt.gca().spines['left'].set_position(('outward', 10)) 



# Adding labels and title
plt.xlabel('Layer Depth', fontweight='bold')
plt.ylabel('Neuron Overlap Rate', fontweight='bold')
plt.legend(
   bbox_to_anchor=(.9, 0.9),
   bbox_transform = plt.gcf().transFigure,
   ncol=1
)

# Show the plot
plt.savefig(f'experiments/scatterplots/bloom-560m/layers.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/markers.py in _set_marker(self, marker)
#     325             try:
# --> 326                 Path(marker)
#     327                 self._marker_function = self._set_vertices
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     128         """
# --> 129         vertices = _to_unmasked_float_array(vertices)
#     130         _api.check_shape((None, 2), vertices=vertices)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1297     else:
# -> 1298         return np.asarray(x, float)
#    1299
#
# ...
